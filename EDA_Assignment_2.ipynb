# %% [markdown]
# **Amazon Sales Data**
#
# **Description:**
#
#
# This dataset contains information on #K+ Amazon products, including their ratings, reviews, and other details.
#
#
# **Features**
#
# product_id: Unique identifier for each product
#
# product_name: Name of the product
#
# category: Category of the product
#
# discounted_price: Discounted price of the product
#
# actual_price: Actual price of the product
#
# discount_percentage: Percentage of discount for the product
#
# rating: Rating of the product (#-5)
#
# rating_count: Number of people who voted for the Amazon rating
#
# about_product: Description about the product
#
# user_id: ID of the user who wrote the review
#
# user_name: Name of the user who wrote the review
#
# review_id: ID of the user review
#
# review_title: Short review
#
# review_content: Long review
#
# img_link: Image link of the product
#
# product_link: Qfficial website link of the product

# %% [markdown]
# **Description of the Dataset:**
#
#
# The dataset titled "Spotify Data: Popular Hip-hop Artists and Tracks" provides a curated collection of
# approximately 500 entries showcasing the vibrant realm of hip-hop music. These entries meticulously compile
# the most celebrated hip-hop tracks and artists, reflecting their significant influence on the genre's landscape.
# Each entry not only highlights the popularity and musical composition of the tracks but also underscores the
# creative prowess of the artists and their profound impact on global listeners.
#
#
# **Application in Data Science:**
#
#
# This dataset serves as a valuable resource for various data science explorations. Analysts can delve into trend
# analysis to discern the popularity dynamics of hit hip-hop tracks over recent years. Additionally, the dataset
# enables network analysis to uncover collaborative patterns among top artists, shedding light on the genre's
# evolving collaborative landscape. Furthermore, it facilitates the development of predictive models aimed at
# forecasting track popularity based on diverse features, offering insights for artists, producers, and marketers.
#
#
#
# **Column Descriptors**:
#
#
# Artist: The name of the artist, providing direct attribution to the creative mind behind the track.
#
# Track Name: The title of the track, encapsulating its identity and essence.
#
# Popularity: A numeric score reflecting the track's reception and appeal among Spotify listeners.
#
# Duration (ms): The track's length in milliseconds, detailing the temporal extent of the musical experience.
#
# Track ID: A unique identifier within Spotify's ecosystem, enabling direct access to the track for further
# exploration.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings as wr
wr.filterwarnings ("ignore")

# %%
df = pd.read_csv("/content/spotify.csv")
df
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %%
# @title category vs rating

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df['category'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='rating', y='category', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Artist         440 non-null    object
#  1   Track Name     440 non-null    object
#  2   Popularity     440 non-null    int64
#  3   Duration (ms)  440 non-null    int64
#  4   Track ID       440 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 17.3+ KB

# %%
df.describe()
# Out:
#        Popularity  Duration (ms)
# count  440.000000     440.000000
# mean    75.736364  206810.040909
# std      9.886534   53576.930289
# min     29.000000   81666.000000
# 25%     70.000000  172778.500000
# 50%     77.000000  201866.000000
# 75%     83.000000  235119.750000
# max     97.000000  501648.000000

# %%
df.head()
# Out:
#   Artist                               Track Name  Popularity  Duration (ms)  \
# 0  Drake  Rich Baby Daddy (feat. Sexyy Red & SZA)          92         319191
# 1  Drake                                One Dance          91         173986
# 2  Drake                       IDGAF (feat. Yeat)          90         260111
# 3  Drake     First Person Shooter (feat. J. Cole)          88         247444
# 4  Drake            Jimmy Cooks (feat. 21 Savage)          88         218364
#
#                  Track ID
# 0  1yeB8MUNeLo9Ek1UEpsyz6
# 1  1zi7xx7UVEFkmKfv06H8x0
# 2  2YSzYUF3jWqb9YP9VXmpjE
# 3  7aqfrAY2p9BUSiupwk3svU
# 4  3F5CgOj3wFlRv51JsHbxhe

# %%
df.tail(3)
# Out:
#         Artist                                         Track Name  Popularity  \
# 437  A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...          69
# 438      Diddy                Another One Of Me (feat. 21 Savage)          65
# 439  Rick Ross                                       Stay Schemin          68
#
#      Duration (ms)                Track ID
# 437         283693  7xVLFuuYdAvcTfcP3IG3dS
# 438         220408  4hGmQboiou09EwhcTWa0H6
# 439         267720  0nq6sfr8z1R5KJ4XUk396e

# %% [markdown]
# ### **QUESTIONS**

# %% [markdown]
# **"1.What is the average rating for each product category**

# %%
import pandas as pd

# Load your dataset
# df = pd.read_csv('path_to_your_dataset.csv')

# Example DataFrame creation for demonstration
data = {
    'category': ['Electronics', 'Electronics', 'Books', 'Books', 'Home'],
    'rating': [4.5, 4.0, 4.8, 4.2, 3.9]
}
df = pd.DataFrame(data)

# Group by category and calculate average rating
average_ratings = df.groupby('category')['rating'].mean().reset_index()

# Rename the columns for better understanding
average_ratings.columns = ['category', 'average_rating']

# Display the average ratings
print(average_ratings)
# Out:
#       category  average_rating
# 0        Books            4.50
# 1  Electronics            4.25
# 2         Home            3.90

# %% [markdown]
# **2. What are the top rating_count products by category?**

# %%
import pandas as pd

data = {
    'category': ['Electronics', 'Electronics', 'Books', 'Books', 'Home', 'Home'],
    'product_name': ['Smartphone A', 'Smartphone B', 'Book A', 'Book B', 'Home Item A', 'Home Item B'],
    'rating_count': [150, 200, 100, 300, 250, 150]
}
df = pd.DataFrame(data)

# Sort products within each category by rating_count and get the top product
top_rating_count = df.loc[df.groupby('category')['rating_count'].idxmax()]

# Display the top products by rating_count for each category
print(top_rating_count)
# Out:
#       category  product_name  rating_count
# 3        Books        Book B           300
# 1  Electronics  Smartphone B           200
# 4         Home   Home Item A           250

# %% [markdown]
# **3. What is the distribution of discounted prices vs. actual prices?**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'discounted_price': [19.99, 25.99, 5.99, 15.99, 9.99, 29.99],
    'actual_price': [24.99, 30.99, 10.99, 20.99, 14.99, 34.99]
}
df = pd.DataFrame(data)

# Set up the figure
plt.figure(figsize=(12, 6))

# Plotting the distributions
plt.subplot(1, 2, 1)
sns.histplot(df['discounted_price'], bins=10, kde=True, color='blue')
plt.title('Distribution of Discounted Prices')
plt.xlabel('Discounted Price')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
sns.histplot(df['actual_price'], bins=10, kde=True, color='orange')
plt.title('Distribution of Actual Prices')
plt.xlabel('Actual Price')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# **4. How does the average discount percentage vary across categories?**

# %%
import pandas as pd

# Load your dataset
# df = pd.read_csv('path_to_your_dataset.csv')

# Example DataFrame for demonstration
data = {
    'category': ['Electronics', 'Electronics', 'Books', 'Books', 'Home', 'Home'],
    'discount_percentage': [20, 30, 15, 25, 10, 5]
}
df = pd.DataFrame(data)

# Group by category and calculate average discount percentage
average_discount = df.groupby('category')['discount_percentage'].mean().reset_index()

# Rename the columns for clarity
average_discount.columns = ['category', 'average_discount_percentage']

# Display the average discounts
print(average_discount)
# Out:
#       category  average_discount_percentage
# 0        Books                         20.0
# 1  Electronics                         25.0
# 2         Home                          7.5

# %% [markdown]
# **5. What are the most popular product names?**

# %%
import pandas as pd

# Load your dataset
# df = pd.read_csv('path_to_your_dataset.csv')

# Example DataFrame for demonstration
data = {
    'product_name': ['Smartphone A', 'Smartphone B', 'Book A', 'Book B', 'Home Item A', 'Home Item B'],
    'rating_count': [150, 200, 100, 300, 250, 150]
}
df = pd.DataFrame(data)

# Sort products by rating_count in descending order
most_popular_products = df.sort_values(by='rating_count', ascending=False)

# Display the top products
top_n = 5  # Change this number to get more or fewer results
print(most_popular_products.head(top_n))
# Out:
#    product_name  rating_count
# 3        Book B           300
# 4   Home Item A           250
# 1  Smartphone B           200
# 0  Smartphone A           150
# 5   Home Item B           150

# %% [markdown]
# **6. What are the most popular product keywords?**

# %%
import pandas as pd
from collections import Counter
import re

# Load your dataset
# df = pd.read_csv('path_to_your_dataset.csv')

# Example DataFrame for demonstration
data = {
    'product_name': ['Smartphone A', 'Smartphone B', 'Book A', 'Book B', 'Home Item A', 'Home Item B'],
}
df = pd.DataFrame(data)

# Function to extract keywords
def extract_keywords(text):
    # Convert to lowercase and remove non-alphanumeric characters
    text = text.lower()
    return re.findall(r'\b\w+\b', text)

# Create a list to hold all keywords
all_keywords = []

# Extract keywords from product names
for name in df['product_name']:
    all_keywords.extend(extract_keywords(name))

# Count the frequency of each keyword
keyword_counts = Counter(all_keywords)

# Convert to DataFrame for easier sorting
keywords_df = pd.DataFrame(keyword_counts.items(), columns=['keyword', 'frequency'])

# Sort by frequency
most_popular_keywords = keywords_df.sort_values(by='frequency', ascending=False)

# Display the top keywords
top_n = 5  # Change this number to get more or fewer results
print(most_popular_keywords.head(top_n))
# Out:
#       keyword  frequency
# 1           a          3
# 2           b          3
# 0  smartphone          2
# 3        book          2
# 4        home          2

# %% [markdown]
# **7. What are the most popular product reviews?**

# %%
import pandas as pd

# Load your dataset
# df = pd.read_csv('path_to_your_dataset.csv')

# Example DataFrame for demonstration
data = {
    'review_id': [1, 2, 3, 4, 5],
    'product_name': ['Smartphone A', 'Smartphone B', 'Book A', 'Book B', 'Home Item A'],
    'rating': [5, 4, 5, 3, 2],
    'rating_count': [150, 200, 100, 300, 50],
    'review_title': ['Excellent!', 'Very good', 'Loved it!', 'Not bad', 'Disappointed'],
    'review_content': ['Best smartphone ever!', 'Great phone with excellent features.', 'An amazing read!', 'Pretty decent book.', 'Did not meet my expectations.'],
}
df = pd.DataFrame(data)

# Sort reviews by rating and rating_count
most_popular_reviews = df.sort_values(by=['rating', 'rating_count'], ascending=False)

# Display the top reviews
top_n = 5  # Change this number to get more or fewer results
print(most_popular_reviews.head(top_n))
# Out:
#    review_id  product_name  rating  rating_count  review_title  \
# 0          1  Smartphone A       5           150    Excellent!
# 2          3        Book A       5           100     Loved it!
# 1          2  Smartphone B       4           200     Very good
# 3          4        Book B       3           300       Not bad
# 4          5   Home Item A       2            50  Disappointed
#
#                          review_content
# 0                 Best smartphone ever!
# 2                      An amazing read!
# 1  Great phone with excellent features.
# 3                   Pretty decent book.
# 4         Did not meet my expectations.

# %%
df.columns
# Out:
# Index(['category', 'rating'], dtype='object')

# %% [markdown]
# **8. What is the correlation between discounted_price and rating?**

# %%
import pandas as pd

# Example data
data = {
    'discounted_price': [19.99, 25.99, 5.99, 15.99, 9.99, 29.99],
    'rating': [4.5, 4.0, 4.8, 4.2, 3.9, 5.0]
}
df = pd.DataFrame(data)

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                   discounted_price    rating
# discounted_price          1.000000  0.186418
# rating                    0.186418  1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Example data
data = {
    'discounted_price': [19.99, 25.99, 5.99, 15.99, 9.99, 29.99],
    'rating': [4.5, 4.0, 4.8, 4.2, 3.9, 5.0]
}
df = pd.DataFrame(data)

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(8, 6))

# Create a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True, cbar=True)

# Add titles and labels
plt.title('Correlation Heatmap')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()

# %% [markdown]
# **9. What are the Top 5 categories based on the highest ratings?**

# %%
import pandas as pd

# Load your dataset
# df = pd.read_csv('path_to_your_dataset.csv')

# Example DataFrame for demonstration
data = {
    'category': ['Electronics', 'Electronics', 'Books', 'Books', 'Home', 'Home'],
    'rating': [4.5, 4.0, 4.8, 4.2, 3.9, 4.1]
}
df = pd.DataFrame(data)

# Group by category and calculate average rating
average_ratings = df.groupby('category')['rating'].mean().reset_index()

# Sort by average rating in descending order
top_categories = average_ratings.sort_values(by='rating', ascending=False)

# Get the top 5 categories
top_5_categories = top_categories.head(5)

# Display the results
print(top_5_categories)
# Out:
#       category  rating
# 0        Books    4.50
# 1  Electronics    4.25
# 2         Home    4.00

# %% [markdown]
# ***10. Identify any potential areas for improvement or optimization based on the data analysis ***

# %% [markdown]
# To identify potential areas for improvement or optimization based on a Spotify dataset, you can analyze various aspects of the data, such as song popularity, artist performance, user engagement, and genre trends. Here are some potential areas for improvement:
#
# **1. Analyzing Song Popularity**
#
# Observation: Identify songs with high play counts but low engagement (e.g., likes or shares).
#
# Action:  Investigate the reasons for low engagement. Consider promotional strategies or collaborations to enhance visibility.
#
# **2. Genre Trends**
#
# Observation:  Examine trends in popular genres over time.
#
# Action:  Optimize playlists and marketing strategies to align with trending genres, ensuring Spotify stays relevant with listener preferences.
#
# **3. User Engagement Analysis**
#
# Observation:  Look at user interaction metrics such as skips, saves, and shares.
#
# Action: If certain songs are frequently skipped, analyze their features (e.g., tempo, mood) to understand listener preferences and adjust recommendations.
#
# **4. Artist Performance Metrics**
#
# Observation: Compare the performance of different artists based on metrics like streams, likes, and follower counts.
#
# Action:  Create promotional campaigns for underperforming artists who have potential based on their growth metrics.
#
# **5. Playlist Effectiveness**
#
# Observation:  Evaluate the performance of curated playlists.
#
# Action: Analyze which playlists drive the most engagement and update or replace less effective ones based on user data.
#
# **6. User Retention Strategies**
#
# Observation: Look for patterns in user churn (e.g., users who stop listening).
#
# Action: Implement retention strategies, such as personalized recommendations or exclusive content, to keep users engaged.
#
# **7. Targeted Marketing Campaigns**
#
# Observation:  Identify user demographics that engage with specific genres or artists.
#
# Action: Create targeted marketing campaigns based on demographic insights to attract new listeners.
#
# **8. Feature Optimization**
#
# Observation: Analyze which features (e.g., playlists, radio, discovery) drive the most user engagement.
#
# Action:  Enhance the most popular features while re-evaluating or improving those that are underused.

# %% [markdown]
# **QUESTIONS**

# %% [markdown]
# **1.Load the dataframe and ensure data quality by checking for missing values and duplicate rows.
#  Handle missing values and remove duplicate rows if necessary.**

# %%
import pandas as pd

# Step 1: Load the DataFrame
# Example: Replace 'path_to_your_dataset.csv' with your actual file path
df = pd.read_csv('/content/spotify.csv')

# Step 2: Check for Missing Values
print("Missing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# Artist           0
# Track Name       0
# Popularity       0
# Duration (ms)    0
# Track ID         0
# dtype: int64

# %% [markdown]
# **2.What is the distribution of popularity among the tracks in the dataset? Visualize it using a histogram.**

# %%
# Step : Check the Popularity Column
# Assuming there is a column named 'popularity'
if 'Popularity' not in df.columns:
    raise ValueError("The 'Popularity' column is not found in the DataFrame.")

# Step 3: Visualize the Distribution
plt.figure(figsize=(10, 6))
plt.hist(df['Popularity'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Track Popularity')
plt.xlabel('Popularity')
plt.ylabel('Number of Tracks')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# **3.Is there any relationship between the popularity and the duration of tracks? Explore this using a scatter plot.**

# %%
# Assuming there are columns named 'popularity' and 'duration_ms'
if 'Popularity' not in df.columns or 'Duration (ms)' not in df.columns:
    raise ValueError("Required columns 'Popularity' or 'Duration (ms)' not found in the DataFrame.")

# Step 3: Create a Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Duration (ms)', y='Popularity', data=df, color='blue', alpha=0.6)
plt.title('Relationship Between Track Popularity and Duration')
plt.xlabel('Duration (ms)')
plt.ylabel('Popularity')
plt.grid()
plt.show()

# %% [markdown]
# **4.Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist
# using a countplot.**

# %%
# Assuming there is a column named 'artist'
if 'Artist' not in df.columns:
    raise ValueError("The 'Artist' column is not found in the DataFrame.")

# Step 3: Count Tracks for Each Artist
track_counts = df['Artist'].value_counts().reset_index()
track_counts.columns = ['Artist', 'track_count']

# Step 4: Visualize with a Countplot
plt.figure(figsize=(12, 6))
sns.barplot(x='track_count', y='Artist', data=track_counts.head(10), palette='viridis')
plt.title('Top 10 Artists by Number of Tracks')
plt.xlabel('Number of Tracks')
plt.ylabel('Artist')
plt.show()

# %% [markdown]
# **5.What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each.**

# %%
# Assuming there are columns named 'track_name', 'artist', and 'popularity'
required_columns = ['Track Name', 'Artist', 'Popularity']
for col in required_columns:
    if col not in df.columns:
        raise ValueError(f"The '{col}' column is not found in the DataFrame.")

# Step 3: Sort the Data by Popularity
least_popular_tracks = df.nsmallest(5, 'Popularity')[['Track Name', 'Artist', 'Popularity']]

# Step 4: Display the Top 5 Least Popular Tracks
print("Top 5 Least Popular Tracks:")
print(least_popular_tracks)
# Out:
# Top 5 Least Popular Tracks:
#                         Track Name          Artist  Popularity
# 207  Attachments (feat. Coi Leray)          Pressa          29
# 231                     Intentions   Justin Bieber          35
# 413                Splash Brothers  French Montana          44
# 435                Splash Brothers  French Montana          44
# 225                  On Me - Remix        Lil Baby          47

# %% [markdown]
# **6.Among the top 5 most popular artists, which artist has the highest popularity on average?
#  Calculate and display the average popularity for each artist.**

# %%
# Assuming there are columns named 'artist' and 'popularity'
if 'Artist' not in df.columns or 'Popularity' not in df.columns:
    raise ValueError("Required columns 'artist' or 'Popularity' not found in the DataFrame.")

# Step 3: Calculate Average Popularity for Each Artist
average_popularity = df.groupby('Artist')['Popularity'].mean().reset_index()

# Step 4: Identify the Top 5 Most Popular Artists
top_artists = average_popularity.nlargest(5, 'Popularity')

# Step 5: Display the Average Popularity for Each of the Top 5 Artists
print("Top 5 Most Popular Artists with Their Average Popularity:")
print(top_artists)
# Out:
# Top 5 Most Popular Artists with Their Average Popularity:
#            Artist  Popularity
# 113         cassö   92.000000
# 104        Trueno   89.000000
# 24   David Guetta   87.000000
# 103  Travis Scott   87.000000
# 114            ¥$   86.090909

# %% [markdown]
# **7.For the top 5 most popular artists, what are their most popular tracks? List the track name for each artist**

# %%
# Assuming there are columns named 'artist', 'track_name', and 'popularity'
required_columns = ['Artist', 'Track Name', 'Popularity']
for col in required_columns:
    if col not in df.columns:
        raise ValueError(f"The '{col}' column is not found in the DataFrame.")

# Step 3: Calculate Average Popularity for Each Artist
average_popularity = df.groupby('Artist')['Popularity'].mean().reset_index()

# Step 4: Identify the Top 5 Most Popular Artists
top_artists = average_popularity.nlargest(5, 'Popularity')

# Step 5: List the Most Popular Track for Each Artist
most_popular_tracks = {}

for artist in top_artists['Artist']:
    # Get the most popular track for the artist
    top_track = df[df['Artist'] == artist].nlargest(1, 'Popularity')[['Track Name', 'Popularity']]
    most_popular_tracks[artist] = top_track

# Display the results
print("Most Popular Tracks for the Top 5 Most Popular Artists:")
for artist, track in most_popular_tracks.items():
    print(f"{artist}: {track['Track Name'].values[0]} (Popularity: {track['Popularity'].values[0]})")
# Out:
# Most Popular Tracks for the Top 5 Most Popular Artists:
# cassö: Prada (Popularity: 92)
# Trueno: Mamichula - con Nicki Nicole (Popularity: 89)
# David Guetta: Baby Don't Hurt Me (Popularity: 87)
# Travis Scott: FE!N (feat. Playboi Carti) (Popularity: 93)
# ¥$: CARNIVAL (Popularity: 96)

# %% [markdown]
# **8.Visualize relationships between multiple numerical variables simultaneously using a pair plot.**

# %%
# Assuming the DataFrame contains numerical columns such as 'popularity', 'duration_ms', 'danceability', etc.
# Adjust the list of columns as needed.
numerical_columns = ['Popularity', 'Duration (ms)']  # Example columns

# Check if all selected columns exist in the DataFrame
for col in numerical_columns:
    if col not in df.columns:
        raise ValueError(f"The '{col}' column is not found in the DataFrame.")

# Step 3: Create a Pair Plot
sns.pairplot(df[numerical_columns])
plt.suptitle('Pair Plot of Numerical Variables', y=1.02)
plt.show()

# %% [markdown]
# **9.Does the duration of tracks vary significantly across different artists?
# Explore this visually using a box plot or violin plot**

# %%
# Assuming there are columns named 'artist' and 'duration_ms'
if 'Artist' not in df.columns or 'Duration (ms)' not in df.columns:
    raise ValueError("Required columns 'Artist' or 'Duration (ms)' not found in the DataFrame.")

# Step 3: Create a Box Plot
plt.figure(figsize=(20,8))
sns.boxplot(x='Artist', y='Duration (ms)', data=df)
plt.title('Track Duration Across Different Artists')
plt.xlabel('Artist')
plt.ylabel('Duration (ms)')
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# **10.How does the distribution of track popularity vary for different artists?
# Visualize this using a swarm plot or a violin plot.**

# %%
# Assuming there are columns named 'artist' and 'popularity'
if 'Artist' not in df.columns or 'Popularity' not in df.columns:
    raise ValueError("Required columns 'artist' or 'popularity' not found in the DataFrame.")

# Step 3: Create a Swarm Plot
plt.figure(figsize=(20, 8))
sns.swarmplot(x='Artist', y='Popularity', data=df, palette='Set2')
plt.title('Track Popularity Across Different Artists')
plt.xlabel('Artist')
plt.ylabel('Popularity')
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.show()
